# %% [raw]
# # Fraud Detection Data Generation
#
# This notebook generates realistic synthetic fraud detection data for training machine learning models.
#
# ## Features Generated:
# - **Customer Demographics**: Age, income, risk profile
# - **Transaction Details**: Amount, timestamp, merchant info
# - **Behavioral Patterns**: Spending habits, transaction frequency
# - **Fraud Indicators**: Time-based, amount-based, location-based patterns
# - **Derived Features**: Aggregations, velocity metrics, statistical features
