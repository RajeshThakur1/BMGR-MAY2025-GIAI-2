# %% [markdown]
# # Demo 3: Group chat — multiple agents talking to each other
#
# **Demo 1** used two agents in a **1:1** chat (`UserProxy` ↔ `AssistantAgent`).
# **Demo 2** showed a **single** custom assistant with its own memory and reply logic.
#
# Here we use **`GroupChat`** + **`GroupChatManager`**: several assistants (plus a user proxy) share one thread. The manager uses the LLM to decide **who speaks next** (`speaker_selection_method="auto"`), so roles can debate, refine ideas, and hand off naturally.

# %%
import os

import autogen
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## LLM config (same idea as Demo 1)
#
# All agents that call the model share this `llm_config`. Set `OPENAI_API_KEY` in `.env`.

# %%
MODEL = os.getenv("AUTOGEN_MODEL", "gpt-4o-mini")

llm_config = {
    "config_list": [
        {
            "model": MODEL,
            "api_key": os.getenv("OPENAI_API_KEY"),
        }
    ],
    "temperature": 0.7,
}

# %% [markdown]
# ## Agents with different roles
#
# - **User_Proxy** — starts the task (`human_input_mode="NEVER"` so the notebook runs without typing at the console; switch to `"ALWAYS"` if you want to join live).
# - **Product_Manager** — scope, users, success criteria.
# - **Engineering_Lead** — architecture, APIs, implementation tradeoffs.
# - **Security_Reviewer** — threats, data handling, least privilege.
#
# They only "communicate" by posting in the same group chat; the **GroupChatManager** picks the next speaker.

# %%
user_proxy = autogen.UserProxyAgent(
    name="User_Proxy",
    human_input_mode="ALWAYS",
    max_consecutive_auto_reply=8,
    code_execution_config={"use_docker": False},
    system_message=(
        "You represent the project owner. You asked for a short plan; listen to the team, "
        "ask at most one clarifying follow-up if needed, then summarize agreements. "
        'When the group has a good enough answer, end with the word TERMINATE on its own line.'
    ),
)


product = autogen.AssistantAgent(
    name="Product_Manager",
    llm_config=llm_config,
    system_message=(
        "You are a product manager. Keep scope small, name user stories and acceptance criteria. "
        "Be concise; respond to engineering and security concerns with pragmatic tradeoffs."
    ),
    code_execution_config={"use_docker": False},
)


engineering = autogen.AssistantAgent(
    name="Engineering_Lead",
    llm_config=llm_config,
    system_message=(
        "You are a senior engineer. Propose a minimal architecture (components, data flow). "
        "Flag complexity and dependencies; do not write huge code blocks—sketches only."
    ),
    code_execution_config={"use_docker": False},
)

security = autogen.AssistantAgent(
    name="Security_Reviewer",
    llm_config=llm_config,
    system_message=(
        "You are a security-minded reviewer. Call out top risks (authn/z, secrets, PII, supply chain). "
        "Suggest concrete mitigations; stay brief and actionable."
    ),
    code_execution_config={"use_docker": False},
)

# %% [markdown]
# ## Group chat + manager
#
# `GroupChatManager` uses the same LLM to route the conversation (`speaker_selection_method="auto"`).
# Tune **`max_round`** to cap cost; increase if you want longer debates.

# %%
agents = [user_proxy, product, engineering, security]


groupchat = autogen.GroupChat(
    agents = agents,
    messages=[],
    max_round=18,
    speaker_selection_method="auto",
    allow_repeat_speaker=True,
)

manager = autogen.GroupChatManager(
    name="GroupChat_Manager",
    groupchat=groupchat,
    llm_config=llm_config,
    code_execution_config={"use_docker": False},
)

# %% [markdown]
# ## Run the discussion
#
# The user proxy **initiates** chat with the **manager** (not a single assistant). The manager broadcasts messages inside the group.

# %%
task = (
    "We want a small internal web app where employees upload CSV expense rows and get a monthly PDF summary. "
    "No mobile app. Discuss scope, a simple architecture, and the main security checks. "
    "End with a bullet summary the owner can approve."
)

user_proxy.initiate_chat(manager, message=task)
# Out:
# User_Proxy (to GroupChat_Manager):
#
# We want a small internal web app where employees upload CSV expense rows and get a monthly PDF summary. No mobile app. Discuss scope, a simple architecture, and the main security checks. End with a bullet summary the owner can approve.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Product_Manager
#
# Product_Manager (to GroupChat_Manager):
#
# ### Scope:
# The web app will allow employees to upload CSV files containing expense data. The app will process these files, aggregate the data, and generate a monthly PDF summary report.
#
# ### User Stories:
# 1. **CSV Upload**
#    As an employee, I want to upload a CSV file of my expenses so that I can summarize them monthly.
#
#    **Acceptance Criteria:**
#    - User can upload CSV files up to 5MB.
#    - The app validates the CSV format and provides error messages for invalid formats.
#
# 2. **Generate PDF Summary**
#    As an employee, I want to generate a PDF summary of my expenses for a selected month so that I can review my spending.
#
#    **Acceptance Criteria:**
#    - The app generates a PDF summary that includes total expenses, categorized expenses, and a breakdown by date.
#    - Users can download the PDF after generation.
#
# 3. **Monthly Summary View**
#    As an employee, I want to view my past monthly summaries so that I can track my expenses over time.
#
#    **Acceptance Criteria:**
#    - Users can view a list of generated PDF summaries by month.
#    - Users can re-download previous summaries.
#
# ### Simple Architecture:
# - **Frontend:** React.js for a responsive web interface.
# - **Backend:** Node.js/Express for handling file uploads and PDF generation.
# - **Database:** MongoDB to store user data and upload records.
# - **Cloud Storage:** AWS S3 for CSV storage and PDF output.
# - **PDF Generation:** A library like PDFKit or Puppeteer to create PDF summaries.
#
# ### Main Security Checks:
# - **Authentication:** Implement user authentication (e.g., JWT) to restrict access.
# - **File Validation:** Ensure uploaded files are checked for valid CSV format and content.
# - **Data Sanitization:** Sanitize all inputs to prevent SQL injection and XSS attacks.
# - **Access Control:** Ensure users can only access their own data and summaries.
# - **Secure Storage:** Use encryption for sensitive data at rest and in transit.
#
# ### Summary for Approval:
# - Develop a web app for employees to upload CSV expense files and generate monthly PDF summaries.
# - Features include CSV upload, PDF generation, and viewing past summaries.
# - Utilize React.js, Node.js/Express, MongoDB, and AWS S3 in a simple architecture.
# - Implement security measures including user authentication, file validation, data sanitization, access control, and secure storage.
#
# Would you like to proceed with this plan?
#
# --------------------------------------------------------------------------------
#
# Next speaker: Engineering_Lead
#
# Engineering_Lead (to GroupChat_Manager):
#
# ### Minimal Architecture Proposal
#
# #### Components:
# 1. **Frontend**
#    - **Framework:** React.js
#    - **Functionality:** User interface for CSV upload, summary generation, and viewing past summaries.
#
# 2. **Backend**
#    - **Framework:** Node.js with Express
#    - **Endpoints:**
#      - `/upload`: Handle CSV file uploads.
#      - `/generate-summary`: Generate and return the PDF summary.
#      - `/summaries`: Fetch a list of past summaries.
#
# 3. **Database**
#    - **Type:** MongoDB
#    - **Collections:**
#      - `users`: Store user details (ID, email, etc.).
#      - `expenses`: Store uploaded expense records (user ID, CSV data, month/year).
#      - `summaries`: Store metadata about generated PDF summaries (user ID, month, PDF URL).
#
# 4. **Cloud Storage**
#    - **Service:** AWS S3
#    - **Functionality:** Store uploaded CSV files and generated PDF summaries.
#
# 5. **PDF Generation**
#    - **Library:** PDFKit or Puppeteer
#    - **Functionality:** Generate PDF summaries from aggregated expense data.
#
# #### Data Flow:
# 1. **User uploads CSV** via the React frontend.
# 2. **Frontend sends CSV** to the Node.js backend (via `/upload` endpoint).
# 3. **Backend validates and processes** the CSV, storing the data in MongoDB.
# 4. **User requests a summary** for a specific month via the frontend.
# 5. **Backend aggregates data** from MongoDB and generates a PDF using the selected library.
# 6. **PDF is stored in AWS S3**, and a URL is returned to the frontend.
# 7. **User can download** the PDF or view a list of past summaries.
#
# #### Complexity and Dependencies:
# - **Complexity:**
#   - User authentication and authorization logic.
#   - Handling CSV parsing and data validation.
#   - PDF generation logic and formatting.
#
# - **Dependencies:**
#   - External libraries: CSV parsing (e.g., `csv-parser`), PDF generation (e.g., `pdfkit`), and AWS SDK for S3.
#   - Database (MongoDB) for storing user and expense records.
#
# #### Security Checks:
# - **Authentication:** Use JWT for user sessions.
# - **Input Validation:** Ensure uploaded CSVs are formatted correctly and contain valid data.
# - **Data Sanitization:** Sanitize all incoming data to prevent security vulnerabilities.
# - **Access Control:** Restrict data access to ensure users can only view their own records.
# - **Secure Storage:** Use HTTPS for data transmission and encrypt sensitive data at rest.
#
# ### Summary for Approval:
# - Create a small internal web app for employees to upload CSV expense data and generate monthly PDF summaries.
# - Key features include CSV upload, PDF generation, and viewing past summaries.
# - Architecture consists of React.js (frontend), Node.js/Express (backend), MongoDB (database), and AWS S3 (storage).
# - Security measures include authentication, input validation, data sanitization, access control, and secure storage.
#
# Shall we move forward with this proposal?
#
# --------------------------------------------------------------------------------
#
# Next speaker: Security_Reviewer
#
# Security_Reviewer (to GroupChat_Manager):
#
# ### Top Risks and Mitigations:
#
# 1. **Authentication and Authorization:**
#    - **Risk:** Unauthorized access to sensitive expense data.
#    - **Mitigation:** Implement robust user authentication using JWT tokens. Enforce role-based access control (RBAC) to ensure users can only access their own records.
#
# 2. **Secrets Management:**
#    - **Risk:** Exposure of API keys or sensitive credentials.
#    - **Mitigation:** Use environment variables for storing secrets. Employ a secrets management tool (like AWS Secrets Manager) to manage and rotate secrets securely.
#
# 3. **Data Exposure (PII):**
#    - **Risk:** Personal Identifiable Information (PII) in expense records could be exposed.
#    - **Mitigation:** Limit data collection to only what is necessary. Implement encryption for PII both in transit (TLS) and at rest (e.g., using S3 server-side encryption).
#
# 4. **Supply Chain Vulnerabilities:**
#    - **Risk:** Use of vulnerable libraries can introduce security flaws.
#    - **Mitigation:** Regularly update dependencies, use tools like `npm audit` or `Snyk` to check for vulnerabilities, and lock dependencies to specific, tested versions.
#
# 5. **Input Validation and Sanitization:**
#    - **Risk:** Malicious CSV uploads can lead to code injection or data corruption.
#    - **Mitigation:** Implement strict validation rules for CSV uploads, rejecting any files that don't meet predefined criteria. Sanitize all inputs before processing.
#
# 6. **Data Leakage through Logs:**
#    - **Risk:** Sensitive data might be inadvertently logged.
#    - **Mitigation:** Ensure that logs do not contain sensitive information (like PII or tokens). Implement log masking where necessary.
#
# ### Summary for Approval:
# - Develop a secure internal web app for employees to upload CSV expense files and generate monthly PDF summaries.
# - Features include CSV upload, PDF generation, and viewing past summaries.
# - Architecture consists of React.js (frontend), Node.js/Express (backend), MongoDB (database), and AWS S3 (storage).
# - Implement security measures: authentication with JWT, input validation, data sanitization, access control, secrets management, and regular dependency audits.
#
# Would you like to proceed with this plan?
#
# --------------------------------------------------------------------------------
#
# Next speaker: User_Proxy
#
# User_Proxy (to GroupChat_Manager):
#
# yes
#
# --------------------------------------------------------------------------------
#
# Next speaker: User_Proxy
#
# User_Proxy (to GroupChat_Manager):
#
# yes please go haead
#
# --------------------------------------------------------------------------------
#
# Next speaker: Engineering_Lead
#
# Engineering_Lead (to GroupChat_Manager):
#
# ### Next Steps for Implementation
#
# 1. **Project Setup:**
#    - Create a repository for the web app.
#    - Set up a development environment with necessary tools (Node.js, MongoDB, React.js).
#
# 2. **Frontend Development:**
#    - Design the user interface with React.js.
#    - Implement the CSV upload component.
#    - Create components for displaying monthly summaries and downloading PDFs.
#
# 3. **Backend Development:**
#    - Set up the Express server and define API endpoints:
#      - `/upload`: Handle CSV uploads.
#      - `/generate-summary`: Generate PDF summaries.
#      - `/summaries`: Fetch past summaries for users.
#    - Implement user authentication with JWT.
#
# 4. **Database Configuration:**
#    - Set up MongoDB and define data models for users, expenses, and summaries.
#    - Ensure proper indexing for efficient queries.
#
# 5. **PDF Generation:**
#    - Choose a library (PDFKit or Puppeteer) and implement the logic to create PDFs from aggregated expense data.
#
# 6. **Cloud Storage Integration:**
#    - Configure AWS S3 for file storage.
#    - Implement logic to securely upload and retrieve CSV files and generated PDFs.
#
# 7. **Security Implementations:**
#    - Enforce input validation and sanitize user inputs.
#    - Implement role-based access control.
#    - Use environment variables and a secrets management tool for sensitive information.
#    - Conduct regular dependency audits to ensure library security.
#
# 8. **Testing:**
#    - Write unit and integration tests for both frontend and backend components.
#    - Perform security testing to identify vulnerabilities.
#
# 9. **Deployment:**
#    - Choose a hosting provider for the web app (AWS, Heroku, etc.).
#    - Set up CI/CD pipelines for automated deployment.
#
# 10. **User Training and Documentation:**
#     - Create user guides for employees on how to use the application.
#     - Document the codebase and architecture for future reference.
#
# ### Summary for Approval:
# - We are proceeding with the development of the secure internal web app as outlined.
# - The project will include the implementation of features, security measures, and thorough testing before deployment.
#
# If all is clear and you approve these next steps, we will initiate the project timeline and allocate resources accordingly. Shall we proceed?
#
# --------------------------------------------------------------------------------
#
# Next speaker: User_Proxy
#
# User_Proxy (to GroupChat_Manager):
#
# yes approved
#
# --------------------------------------------------------------------------------
#
# Next speaker: Engineering_Lead
#
# Engineering_Lead (to GroupChat_Manager):
#
# ### Project Kickoff
#
# Thank you for the approval! We will now initiate the project. Here’s a quick recap of the timeline and key milestones:
#
# ### Project Timeline and Milestones
#
# 1. **Week 1-2: Project Setup and Initial Development**
#    - Establish the repository and environment.
#    - Begin frontend development with React.js.
#    - Set up the backend using Node.js/Express.
#
# 2. **Week 3: Database and API Development**
#    - Configure MongoDB and define data models.
#    - Implement API endpoints for CSV uploads and PDF generation.
#
# 3. **Week 4: PDF Generation and Cloud Integration**
#    - Integrate chosen PDF generation library.
#    - Configure AWS S3 for file storage and implement upload logic.
#
# 4. **Week 5: Security Implementations**
#    - Implement JWT authentication and role-based access control.
#    - Conduct input validation, data sanitization, and secrets management.
#
# 5. **Week 6: Testing Phase**
#    - Write unit and integration tests.
#    - Conduct security testing for vulnerabilities.
#
# 6. **Week 7: Deployment**
#    - Set up hosting and CI/CD pipelines.
#    - Deploy the application for internal use.
#
# 7. **Week 8: User Training and Documentation**
#    - Create user guides and documentation for the application.
#    - Conduct training sessions for employees.
#
# ### Regular Updates
# We will provide regular updates on progress and any challenges encountered. If there are any changes or additional requirements, please feel free to reach out.
#
# Let’s get started, and I’ll keep you informed at each milestone! Thank you for your support!
#
# --------------------------------------------------------------------------------
#
# Next speaker: User_Proxy
#
# User_Proxy (to GroupChat_Manager):
#
# Thanks
#
# --------------------------------------------------------------------------------
#
# Next speaker: User_Proxy
#
# User_Proxy (to GroupChat_Manager):
#
# thanks please go ahead
#
# --------------------------------------------------------------------------------
#
# Next speaker: Engineering_Lead
#
# Engineering_Lead (to GroupChat_Manager):
#
# ### Execution of Project Plan
#
# We are now officially underway with the development of the internal web app for expense management. Here’s a concise outline of our immediate actions:
#
# 1. **Initial Setup:**
#    - Create repository: Set up a GitHub or GitLab repository for version control.
#    - Environment setup: Ensure that all team members have the necessary tools and dependencies installed (Node.js, MongoDB, React.js).
#
# 2. **Frontend Development:**
#    - Start with a basic layout using React.
#    - Implement the CSV upload functionality with file validation.
#    - Create components for viewing summaries and downloading PDFs.
#
# 3. **Backend Development:**
#    - Initialize the Express server.
#    - Define the initial API endpoints for handling requests.
#    - Set up JWT authentication for user sessions.
#
# 4. **Database Configuration:**
#    - Set up MongoDB with collections for users, expenses, and summaries.
#    - Create basic data models.
#
# 5. **Cloud Storage:**
#    - Configure AWS S3 for secure storage of uploaded files and generated PDFs.
#
# ### Communication and Collaboration
# - **Weekly Stand-ups:** We will hold weekly meetings to discuss progress, address blockers, and plan next steps.
# - **Documentation:** All decisions and changes will be documented in a shared space for transparency.
#
# ### Risk Management
# We will continuously monitor potential risks and apply the mitigations discussed earlier to ensure the security and stability of the application.
#
# ### Next Steps
# - Team members will begin their assigned tasks immediately.
# - Expect the first update at the end of Week 1, highlighting initial progress and any challenges faced.
#
# Thank you for your support and trust as we move forward with this project! If you have further questions or need clarifications, please don't hesitate to ask.
#
# --------------------------------------------------------------------------------
#
# Next speaker: User_Proxy
